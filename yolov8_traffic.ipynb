# %%
import os

# %%
import glob

# %%
from IPython.display import Image, display

# %%
from IPython import display

# %%
display.clear_output()

# %%
# !nvidia-smi
# Out:
# Tue Oct 29 08:25:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
HOME = os.getcwd()

# %%
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vMnOPtmxbGhXHPs3BW96")
project = rf.workspace("roboflow-100").project("road-signs-6ih4y")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to road-signs-2 in yolov5pytorch:: 100%|██████████| 4198/4198 [00:00<00:00, 7192.22it/s]

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {dataset.location}
# Out:
# [Errno 2] No such file or directory: '/content/road-signs-2'
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/roadsign/data.yaml epochs=100 imgsz=640
# Out:
# /content
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image("/content/runs/detect/train6/train_batch0.jpg")

# %%
Image("/content/roadsign/train/images/lampu-hijau--13-_jpg.rf.c8f91c7d92d0b79926c33a2b3425054e.jpg")

# %%
Image("/content/runs/detect/train6/val_batch2_labels.jpg")

# %%
Image("/content/runs/detect/train6/val_batch2_pred.jpg")
